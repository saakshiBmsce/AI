# %%
def manhattan_dis(x1,x2,y1,y2):
    return abs(x2-x1)+abs(y2-y2)

# %%
def is_final(grid):
    final=[[1,2,3],[4,0,5],[6,7,8]]
    if(grid==final):
        return True;
    else:
        return False;

# %%
def hueristic1(grid,goal,goalhash):
    h1=0
    for i in range(0,3):
        for j in range(0,3):
            h1+=manhattan(i,j,goalhash[grid[i][j]][0],goalhash[grid[i][j]][0])
    return h1

# %%
def hueristic2(grid,goal):
    h2=0
    for i in range(0,3):
        for j in range(0,3):
            if(grid[i][j]!=goal[i][j]):
                h2+=1
    return h2

# %%
def dfs(grid,x,y,visited):
    s=str_val(grid)
    if((x<0)or(y<0)or(x>=3)or(y>=3)):
        return false;
    if(s in visited):
        return false;
    if(is_final(grid)):
        return true;
    ways=[[1,0],[0,1],[-1,0],[0,-1]];
    minx=0
    miny=0
    mindis=9
    for way in ways:
        nx=x+way[0]
        ny=y+way[1]
        if((nx<0)or(ny<0)or(nx>=3)or(ny>=3)):
            continue;
        if(manhattan_dis(x1,x2,y1,y2)<mindis):
            mindis=manhattan_dis(x1,x2,y1,y2)
            minx=nx
            miny=ny
    dfs()

# %%
def search(grid,init,goal):
    visited = [[0 for col in range(len(grid[0]))] for row in range(len(grid))]
    visited[init[0]][init[1]] = 1

    x = init[0]
    y = init[1]
    f = hueristic2(x,y)

    open = [[f, x, y]]

    found = False  # flag that is set when search is complete
    deadend = False # flag set if we can't find expand
    count = 0
    
    while not found and not deadend:
        if len(open) == 0:
            deadend = True
            return "Failed"
        else:
            open.sort()
            open.reverse()
            next = open.pop()
            f = next[0]
            x = next[2]
            y = next[3]
            
            if grid
                found = True
            else:
                for i in range(len(delta)):
                    x2 = x + delta[i][0]
                    y2 = y + delta[i][1]
                    if x2 >= 0 and x2 < len(grid) and y2 >=0 and y2 < len(grid[0]):
                        if visited[x2][y2] == 0 and grid[x2][y2] == 0:
                            g2 = g + cost
                            f = g2 + heuristic[x2][y2]
                            open.append([f, g2, x2, y2])
                            visited[x2][y2] = 1
    return path

# %%
grid=[[1,0,3],[4,2,5],[6,7,8]]
goal=[[1,2,3],[4,0,5],[6,7,8]]
goalhash=[[0,0],[0,1],[0,2],[1,0],[1,2],[2,0],[2,1],[2,2]]
bfs(grid,0,1)
# Out:
# queue:  [[0, 1, [[1, 0, 3], [4, 2, 5], [6, 7, 8]]]]
# [0, 1, [[1, 0, 3], [4, 2, 5], [6, 7, 8]]]
# nx: 0 ny: 2
# changes queue :  []
# changed grid:  [[1, 3, 0], [4, 2, 5], [6, 7, 8]]
# changes queue :  [[0, 2, [[1, 3, 0], [4, 2, 5], [6, 7, 8]]]]
# nx: 1 ny: 1
# changes queue :  [[0, 2, [[1, 0, 3], [4, 2, 5], [6, 7, 8]]]]
# changed grid:  [[1, 2, 3], [4, 0, 5], [6, 7, 8]]
# changes queue :  [[0, 2, [[1, 2, 3], [4, 0, 5], [6, 7, 8]]], [1, 1, [[1, 2, 3], [4, 0, 5], [6, 7, 8]]]]
# nx: 0 ny: 0
# changes queue :  [[0, 2, [[1, 0, 3], [4, 2, 5], [6, 7, 8]]], [1, 1, [[1, 0, 3], [4, 2, 5], [6, 7, 8]]]]
# changed grid:  [[0, 1, 3], [4, 2, 5], [6, 7, 8]]
# changes queue :  [[0, 2, [[0, 1, 3], [4, 2, 5], [6, 7, 8]]], [1, 1, [[0, 1, 3], [4, 2, 5], [6, 7, 8]]], [0, 0, [[0, 1, 3], [4, 2, 5], [6, 7, 8]]]]
# nx: -1 ny: 1
# queue:  [[0, 2, [[1, 0, 3], [4, 2, 5], [6, 7, 8]]], [1, 1, [[1, 0, 3], [4, 2, 5], [6, 7, 8]]], [0, 0, [[1, 0, 3], [4, 2, 5], [6, 7, 8]]]]
# ...
